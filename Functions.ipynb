# %%
def scream():
    print('Hello World')
scream()
# Out:
# Hello World

# %%
def square(num):
    out = num**2
    return(out)

# %%
sq_3 = square(3)
print(sq_3)
# Out:
# 9
# None

# %%
def square(num):
    out = num**2
    print(out)

# %%
q = square(4)
print("Q is"+str(q))
# Out:
# 16
# Q isNone

# %%
def factorial(n):
    if n>1:
        return n*factorial(n-1)
    else:
        return n

fact = factorial(5)
print(fact)
# Out:
# 120

# %%
def addition(*args):
    print(args)
    return(sum(args))

# %%
print(addition(4,5,6,7,8,9))
print(addition(1,2))
# Out:
# (4, 5, 6, 7, 8, 9)
# 39
# (1, 2)
# 3

# %%
def proper(some_text):
    some_text = some_text.strip()
    some_text = " ".join([word[0].upper() + word[1:] for word in some_text.split()])
    return some_text

captain = proper("mahendra singh dhoni")
print(captain)


print(" ".join([word[0].upper()+word[1:] for word in "mahendra singh dhoni".split()]))
# Out:
# Mahendra Singh Dhoni
# Mahendra Singh Dhoni

# %%
string_to_list = lambda x: x.split()
print(string_to_list(captain))
print(type(string_to_list))
# Out:
# ['Mahendra', 'Singh', 'Dhoni']
# <class 'function'>

# %%
product = lambda x, y : x*y
print(product(3,4))
# Out:
# 12

# %%
Nameformator = lambda Name: " ".join([word[0].upper() + word[1:] for word in Name.split()])

print(Nameformator("ranganadh Kodali"))
# Out:
# Ranganadh Kodali

# %%
FullName = lambda *name : 
greater = lambda x,y: x if x >y else y

print(greater(a,b))

print(FullName('Ranganadh','Kodali','Tenali'))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-27-17d81ec8f284> in <module>
#       1 FullName = lambda *name : " ".join(name[0].upper() + name[1:])
#       2
# ----> 3 print(FullName('Ranganadh','Kodali','Tenali'))
#
# <ipython-input-27-17d81ec8f284> in <lambda>(*name)
# ----> 1 FullName = lambda *name : " ".join(name[0].upper() + name[1:])
#       2
#       3 print(FullName('Ranganadh','Kodali','Tenali'))
#
# TypeError: can only concatenate str (not "tuple") to str

# %%
a=30
b=20


greater = lambda x,y: x if x >y else y

print(greater(a,b))
# Out:
# 30

# %%
a=[1,2,3,4]
b=[6,7,7]

a[2:2]=b

print(a)
# Out:
# [1, 2, 6, 7, 7, 3, 4]
