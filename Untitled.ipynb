# %%
import pandas as pd
import numpy as np
import scipy as sp
import plotly.plotly as py
import cufflinks as cf
from sklearn.decomposition import PCA

from sklearn.decomposition import IncrementalPCA

from plotly.offline import download_plotlyjs, init_notebook_mode, iplot
init_notebook_mode(connected=True)

from sklearn.cluster import KMeans

#Metrics and measures 
from sklearn.metrics import silhouette_score



pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
# ...

# %%
data = pd.read_csv(f"Z:\August 2019\Postpaid revenue\JNL_Aug19.txt",sep="|")

# %%
data.groupby(["SUBS_CATEGORY_CODE_V"])["TRANS_AMT_N"].sum().iplot(kind="bar")

# %%
data.columns = ['SUBS_CATEGORY_CODE_V', 'SUBS_SUB_CATEGORY_CODE_V', 'PRODUCT_NAME', 'ARTICLE_CODE_V ', 'ARTICLE_CATEGORY_V', 'FINACC_CATEGORY_V ', 'ARTICLE_DESC_V', 'DB_CR_V', 'TRANS_AMT_N', 'DISC_AMT', 'TOT_AMT', 'TYPE_V', 'TRANS_DATE_D']

# %%
data
# Out:
#        SUBS_CATEGORY_CODE_V  SUBS_SUB_CATEGORY_CODE_V                 PRODUCT_NAME  ARTICLE_CODE_V  ARTICLE_CATEGORY_V FINACC_CATEGORY_V                    ARTICLE_DESC_V DB_CR_V  TRANS_AMT_N  DISC_AMT  TOT_AMT   TYPE_V                         TRANS_DATE_D
# 0                         1                         1       100 GB data - MWASALAT       1130000189                  U                  I                     Data Charges       C         0.00     0.000    0.000  REGULAR  31-AUG-19 11.59.59.000000 PM +04:00
# 1                         1                         1       100 GB data - MWASALAT       1130003608                  U                  I         VUCLIP Activation Charge       C         0.60     0.000    0.600  REGULAR  31-AUG-19 11.59.59.000000 PM +04:00
# ...
