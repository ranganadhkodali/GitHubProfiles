# %% [markdown]
# ## algorithm

# %%
def count_of_1bits(value):
    n = 0
    while value:
        print (value)
        value &= value - 1
        n += 1
    return n

# %% [markdown]
# ## run

# %%
count_of_1bits(0)
# Out:
# 0

# %%
count_of_1bits(1)
# Out:
# 1

# %%
count_of_1bits(0b11000000)
# Out:
# 192
# 128
# 2

# %%
192& (192-1) &(128-1)
# Out:
# 0
