# %%
import time

class Clock(object):
    def __init__(self, hour, minute):
        self.hour = hour + minute //60
        self.minute = minute % 60
        
    def __repr__(self):
        if self.hour % 24 < 10:
            h = "0"+ str(self.hour % 24)
        else:
            h = str(self.hour % 24)
        if self.minute < 10:
            m = "0" + str(self.minute)
        else:
            m = str(self.minute)
        return (f"{h}:{m}")

# %%
class Luhn(object):
    def __init__(self, card_num):
        self.num = card_num

    def is_valid(self):
        digits=[]
        i=0
        for n in self.num[0:]:
            if n ==" ": 
                continue
            try:
                n = int(n)
            except:
                return False

            if (i == 0 ):
                n= n *2

                if n>=9 :
                    n = n-9
                digits.append(n)
                i=1
            else :
                digits.append(n)
                i=0
        return  sum(digits) % 10 ==0 and len(digits) >1
    
    def is_valid1(self):
        self.num = self.num.replace(" ","")
        if(len(self.num) <=1) or (self.num.isdigit() == False) :
            return False
        else :

# %%
import math

print(729 **(1/3) )

print (3**5)

print (81 * 9)
# Out:
# 8.999999999999998
# 243
# 729
