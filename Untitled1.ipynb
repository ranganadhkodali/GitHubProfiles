# %%
from bs4 import BeautifulSoup

# %%
data =r'<!DOCTYPE html> \
<html> \
<head>	 \
    <title>MyWebPage</title> \
    <link href="https://fonts.googleapis.com/css?family=Oswald" rel="stylesheet"> \
    <link href= "style.css" type= "text/css" rel="stylesheet"> \
</head> \
<body> \
    <div class="review-body"> \
        The Godfather \
        The Godfather (1972) is the greatest movie of all time, \
               according to numerous surveys of movie critics and audiences alike \
        <p>The Godfather is... (your review here) \
    </div> \
    <div class="review-body"> \
        Avatar \
        Avatar (2009) is the highest grossing film of all time,  \
               earning approximately $2.8 billion. \
        Avatar is... (your review here) \
    </div> \
</body> \
</html>'

# %%
soup = BeautifulSoup(data, 'html.parser')

li =soup.find_all("div",class_="review-body")

[i.text for i in soup.find_all("div",class_="review-body")]
# Out:
# [' \\\n        The Godfather \\\n        The Godfather (1972) is the greatest movie of all time, \\\n               according to numerous surveys of movie critics and audiences alike \\\n        The Godfather is... (your review here) \\\n    ',
#  ' \\\n        Avatar \\\n        Avatar (2009) is the highest grossing film of all time,  \\\n               earning approximately $2.8 billion. \\\n        Avatar is... (your review here) \\\n    ']

# %%
shopping=["apple",2,'liquid blu',3,'timber']
selective=[]
for x in shopping:
    if str(x).startswith("a"):
        selective.append(x)
print(selective)
# Out:
# ['apple']

# %%
shopping=["apple",2,'liquid blu',3,'timber']
selective=[]
for x in shopping:
    
    if type(x) == str :
        if str(x).startswith("a"):
            selective.append(x)
print(selective)
# Out:
# ['apple']

# %%
syt = "test"
# Out:
# str
