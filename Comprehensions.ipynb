# %%
squares_list= []

for xi, in range(1,10):
    squares_list.append(x**2)
print(squares_list)
# Out:
# [1, 4, 9, 16, 25, 36, 49, 64, 81]

# %%
myli=["ranganadh "+str(x) for x in range(1,10)]

for i,x in enumerate(myli) :
    print (f"list for {i} myli {x}")
# Out:
# list for 0 myli ranganadh 1
# list for 1 myli ranganadh 2
# list for 2 myli ranganadh 3
# list for 3 myli ranganadh 4
# list for 4 myli ranganadh 5
# list for 5 myli ranganadh 6
# list for 6 myli ranganadh 7
# list for 7 myli ranganadh 8
# list for 8 myli ranganadh 9

# %%
squares_list = [x**2 for x in range(1,10)]
print(squares_list)
# Out:
# [1, 4, 9, 16, 25, 36, 49, 64, 81]

# %%
mylist = [word for sentence in paragraph for word in sentence.split()]
print(mylist)
# Out:
# ['There', 'was', 'a', 'fox.', 'It', 'was', 'brown', 'in', 'color.', 'It', 'was', 'seen', 'near', 'that', 'farm', 'sometime', 'back']

# %%
[ for word (sentence for sentence in paragraph) for ]
# Out:
# ['There was a fox.',
#  'It was brown in color.',
#  'It was seen near that farm sometime back']

# %%
paragraph = ["There was a fox." , 'It was brown in color.', "It was seen near that farm sometime back"]

single_word_list =[]

for sentence in paragraph:
    for word in sentence.split():
        single_word_list.append(word)

print(single_word_list)
# Out:
# ['There', 'was', 'a', 'fox.', 'It', 'was', 'brown', 'in', 'color.', 'It', 'was', 'seen', 'near', 'that', 'farm', 'sometime', 'back']

# %%
# ['There', 'was', 'a', 'fox.', 'It', 'was', 'brown', 'in', 'color.', 'It', 'was', 'seen', 'near', 'that', 'farm', 'sometime', 'back']

# %%
single_word_list =[]

for sentence in paragraph:
    for word in sentence.split():
        single_word_list.append(word)

print(single_word_list)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-a13358eb490b> in <module>
#       1 single_word_list =[]
#       2
# ----> 3 for sentence in paragraph:
#       4     for word in sentence.split():
#       5         single_word_list.append(word)
#
# NameError: name 'paragraph' is not defined

# %%
single_word_list  = [word for sentence in paragraph for word in sentence.split()]
print(single_word_list)

# %%
vowels = ['a','e','i','o','u']
mylist = [word for sent in paragraph for word in sent.split() if word[0].lower() in vowels]
print(mylist)
# Out:
# ['a', 'It', 'in', 'It']

# %%
#list comp with if statement
vowels = ['a','e','i','o','u']
vowels_from_sentence =[]
for sentence in paragraph:
    for word in sentence.split():
        if word[0].lower() in vowels:
            vowels_from_sentence.append(word)

print(vowels_from_sentence)
# Out:
# ['a', 'It', 'in', 'It']

# %% [markdown]
# #[ for sentence in paragraph]
# #[ for sentence in paragraph for word in sentence.split()]

# %%
vowels_comp = [word for sentence in paragraph for word in sentence.split() if word[0].lower() in vowels]
print(vowels_comp)
# Out:
# ['a', 'It', 'in', 'It']

# %%
squared_dictionary = {num : num**2 for num in range(0, 25)}
print(squared_dictionary)
# Out:
# {0: 0, 1: 1, 2: 4, 3: 9, 4: 16, 5: 25, 6: 36, 7: 49, 8: 64, 9: 81, 10: 100, 11: 121, 12: 144, 13: 169, 14: 196, 15: 225, 16: 256, 17: 289, 18: 324, 19: 361, 20: 400, 21: 441, 22: 484, 23: 529, 24: 576}

# %%
students_data = {1:['Shivam Bansal', 24] , 2:['Udit Bansal',25], 3:['Sonam Gupta', 26], 4:['Saif Ansari',24], 5:['Huzefa Calcuttawala',27]}

# %%
mydic={key:value[0] for key,value in students_data.items() if key%2==0}
print(mydic)
# Out:
# {2: 'Udit Bansal', 4: 'Saif Ansari'}

# %%
names_comp = {roll_num:details[0] for roll_num,details in students_data.items() if roll_num%2==0}
print(names_comp)
# Out:
# {2: 'Udit Bansal', 4: 'Saif Ansari'}

# %%
n=4

mylist = [i**2 for i in range(1,n+1)]
# Write your code here (remember to print the list)
print(mylist)
# Out:
# [1, 4, 9, 16]

# %%
print(['a','b','c']+['1','2','3'])

print([a+b for a in "abc" for b in "def"])
# Out:
# ['a', 'b', 'c', '1', '2', '3']
# ['ad', 'ae', 'af', 'bd', 'be', 'bf', 'cd', 'ce', 'cf']

# %%
n=10
dictionary = {x:x**2 for x in range(1,n+1)}
print(dictionary)
# Out:
# {1: 1, 2: 4, 3: 9, 4: 16, 5: 25, 6: 36, 7: 49, 8: 64, 9: 81, 10: 100}
